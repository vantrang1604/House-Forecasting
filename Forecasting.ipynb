# %%
# Import the data files 
import pandas as pd
df = pd.read_csv('/Users/trangnguyen/Downloads/forecast_history.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Median house price Westpac: 4 year forecast  \
# 0        2011             340000                      56%
# 1        2012             370000                      53%
# 2        2013             350000                      NaN
# 3        2014             420000                      13%
# 4        2015             425000                      33%
#
#   Joe Bloggs: 2 year forecast Harry Spent: 5 year forecast
# 0                         23%                         -20%
# 1                         34$                         -80%
# 2                         19%                         -70%
# 3                         42%                         -80%
# 4                         23%                         -50%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    12 non-null     int64
#  1   Median house price            12 non-null     object
#  2   Westpac: 4 year forecast      12 non-null     object
#  3   Joe Bloggs: 2 year forecast   12 non-null     object
#  4   Harry Spent: 5 year forecast  12 non-null     object
#  5   Year                          12 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 672.0+ bytes

# %%
df['Year'] = df['Unnamed: 0']

# %%
# Handle missing value
df = df.dropna()

# %%
# Compare the price over the year
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Median house price'], label='Median House Price')

# %%
# Get the Joe Bloggs forecast:
plt.plot(df['Year'], df['Joe Bloggs: 2 year forecast'], label='Joe Bloggs forecast')

# %%
# Get the Westpac forecast:
plt.plot(df['Year'], df['Westpac: 4 year forecast'], label='Westpac forecast')

# %%
# Get the Harry Spent forecast:
plt.plot(df['Year'], df['Harry Spent: 5 year forecast'], label='Harry Spent forecast')

# %% [markdown]
# ## Comparison:
# Looking at all the chart, we could see that the Westpac showed the similar trend to the actual historical trends, as the house price increases significantly over time. The problem with JoeBloggs was that is has too many wrong format
